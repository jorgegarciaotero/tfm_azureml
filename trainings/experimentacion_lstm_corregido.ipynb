# %%
# !pip install adlfs
# !pip install keras-tuner --quiet
# Out:
# Requirement already satisfied: adlfs in /usr/local/lib/python3.11/dist-packages (2024.12.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /usr/local/lib/python3.11/dist-packages (from adlfs) (1.34.0)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.53 in /usr/local/lib/python3.11/dist-packages (from adlfs) (0.0.53)
# Requirement already satisfied: azure-identity in /usr/local/lib/python3.11/dist-packages (from adlfs) (1.23.0)
# Requirement already satisfied: azure-storage-blob>=12.17.0 in /usr/local/lib/python3.11/dist-packages (from adlfs) (12.25.1)
# Requirement already satisfied: fsspec>=2023.12.0 in /usr/local/lib/python3.11/dist-packages (from adlfs) (2025.3.2)
# Requirement already satisfied: aiohttp>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from adlfs) (3.11.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs) (6.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs) (1.20.1)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from azure-core<2.0.0,>=1.28.0->adlfs) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from azure-core<2.0.0,>=1.28.0->adlfs) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from azure-core<2.0.0,>=1.28.0->adlfs) (4.14.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.11/dist-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs) (1.17.1)
# Requirement already satisfied: msal<2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs) (1.32.3)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob>=12.17.0->adlfs) (43.0.3)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob>=12.17.0->adlfs) (0.7.2)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from azure-identity->adlfs) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi->azure-datalake-store<0.1,>=0.0.53->adlfs) (2.22)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.53->adlfs) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->adlfs) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->adlfs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->adlfs) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->adlfs) (2025.6.15)

# %% [markdown]
# #### IMPORTS

# %%
# Basics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yaml
import random
import plotly.express as px
import joblib
from datetime import timedelta
from typing import List, Tuple, Dict,Optional

# Azure
from adlfs import AzureBlobFileSystem

from typing import Tuple, List, Optional
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
import pandas as pd


# Models
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler,LabelEncoder
from sklearn.base import TransformerMixin
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc ,  precision_score, recall_score
from tensorflow.keras.metrics import AUC, Precision, Recall
from sklearn.utils import class_weight

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU,Bidirectional,BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import AUC, Precision, Recall
from keras_tuner import RandomSearch

# %% [markdown]
# #### FUNCTIONS

# %%
def load_data_from_dl(account_name: str,container_name: str,relative_path: str,access_key: str)->pd.DataFrame:
    """
    Loads all Parquet files from an Azure Blob Storage path into a single DataFrame.
    Args:
        - account_name (str): Azure Storage account name.
        - container_name (str): Name of the container.
        - relative_path (str): Path inside the container to search for .parquet files.
        - access_key (str): Storage account access key.
    Returns:
        - df (pd.DataFrame): Combined DataFrame from all found Parquet files.
    Raises:
        - ValueError: If no Parquet files are found in the path.
    """
    abfs = AzureBlobFileSystem(account_name=account_name, account_key=access_key)


    all_files = abfs.glob(f"{container_name}/{relative_path}/*.parquet")
    print(f"folder: {all_files}")

    if not all_files:
        raise ValueError("Not found .parquet files")

    dfs = []
    for f in all_files:
        print(f"Reading files: {f}")
        with abfs.open(f, "rb") as fp:
            dfs.append(pd.read_parquet(fp))

    df = pd.concat(dfs, ignore_index=True)
    print(df.head())
    return df

# %%
def model_evaluation(
    y_test: pd.Series,
    y_pred: pd.Series,
    y_prob: pd.Series
) -> Tuple[float, float, float, np.ndarray, float, float]:
    """
    Evaluates the classification model and plots metrics.

    Args:
        y_test (pd.Series): True target values.
        y_pred (pd.Series): Predicted class values.
        y_prob (pd.Series): Predicted probabilities for class 1.

    Returns:
        Tuple containing Accuracy, F1 Score, ROC AUC, Confusion Matrix, Precision, Recall.
    """
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc = roc_auc_score(y_test, y_prob)
    cm = confusion_matrix(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)

    print(f"Accuracy: {acc:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"ROC AUC: {roc:.4f}")
    print(f"Confusion Matrix:\n{cm}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")

    fig, ax = plt.subplots(figsize=(5, 4))
    cax = ax.matshow(cm, cmap='Blues')
    fig.colorbar(cax)
    ax.set_xticks([0, 1])
    ax.set_yticks([0, 1])
    ax.set_xticklabels(['No', 'Yes'])
    ax.set_yticklabels(['No', 'Yes'])
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()

    fpr, tpr, _ = roc_curve(y_test, y_prob)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 4))
    plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return acc, f1, roc, cm, precision, recall

# %%
def clean_columns(df: pd.DataFrame) -> pd.DataFrame:
  """
  Cleans a DataFrame by dropping unnecessary columns and handling missing values.

  Args:
      df (pd.DataFrame): Input DataFrame.

  Returns:
      pd.DataFrame: Cleaned DataFrame.
  """
  columns_to_drop = [
      'capital_gains',
      'ret_next_3m', 'ret_next_6m', 'ret_next_1y',
      'price_lead_3m', 'price_lead_6m', 'price_lead_1y',
      'open_v', 'high', 'low', 'dividends', 'stock_splits',
      'is_dividend_day', 'is_stock_split', 'gap_open', 'price_range',
      'tr_1', 'tr_2', 'tr_3', 'sma_5', 'bollinger_upper',
      'bollinger_lower', 'ema_12', 'macd_line'
  ]


  print(f"Shape before: {df.shape}")
  df = df.drop(columns=columns_to_drop, errors='ignore').copy()
  numeric_cols = df.select_dtypes(include=["float64", "int64", "int32"]).columns
  imputer = SimpleImputer(strategy="mean")
  df[numeric_cols] = imputer.fit_transform(df[numeric_cols])
  print(f"Shape after: {df.shape}")
  return df;

# %%
def prepare_data(
    df: pd.DataFrame,
    targets: list
):
    """
    Prepares a DataFrame for LSTM modeling: imputes missing values and applies MinMax scaling.

    Args:
        df (pd.DataFrame): Input data with features + target + symbol + date.
        targets (list): List of target column names.

    Returns:
        pd.DataFrame: Scaled dataframe with symbol and date preserved.
        MinMaxScaler: The fitted scaler object.
    """
    df_clean = df.copy()

    # Separar columnas a preservar
    symbol_col = df_clean["symbol"]
    date_col = df_clean["date"]

    # Eliminar columnas no necesarias para el modelo
    df_clean = df_clean.drop(columns=["symbol", "date"], errors="ignore")

    # Codificación de categóricas si existieran (seguridad)
    for col in df_clean.select_dtypes(include=["object", "category"]).columns:
        df_clean[col] = LabelEncoder().fit_transform(df_clean[col].astype(str))

    # Separar features y targets
    feature_cols = [col for col in df_clean.columns if col not in targets]
    X = df_clean[feature_cols]
    y = df_clean[targets]

    # Imputación + escalado
    imputer = SimpleImputer(strategy="mean")
    X_imputed = imputer.fit_transform(X)

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X_imputed)

    df_scaled = pd.DataFrame(X_scaled, columns=feature_cols, index=df_clean.index)
    df_scaled = pd.concat([df_scaled, y], axis=1)

    # Reincorporar columnas para split posterior
    df_scaled["symbol"] = symbol_col.values
    df_scaled["date"] = date_col.values

    print(f"df_scaled: {df_scaled.shape}")
    print(f"columns: {df_scaled.columns}")
    return df_scaled, scaler

# %%
def split_by_symbol (df, target_column, test_size=0.2):
    train_rows, test_rows = [], []

    for symbol in df["symbol"].unique():
        df_symbol = df[df["symbol"] == symbol].copy()
        df_symbol = df_symbol.sort_values("date")

        split_idx = int(len(df_symbol) * (1 - test_size))
        train_rows.append(df_symbol.iloc[:split_idx])
        test_rows.append(df_symbol.iloc[split_idx:])

    df_train = pd.concat(train_rows)
    df_test = pd.concat(test_rows)

    X_train = df_train.drop(columns=[target_column])
    y_train = df_train[target_column]

    X_test = df_test.drop(columns=[target_column])
    y_test = df_test[target_column]

    return X_train, X_test, y_train, y_test

# %%
def build_and_split_sequences_by_symbol(
    df: pd.DataFrame,
    target_column: str,
    sequence_length: int = 60,
    test_size: float = 0.2
):
    """
    Builds sequential data for each symbol independently and performs temporal train-test split.

    Args:
        df (pd.DataFrame): Preprocessed DataFrame with features and target.
        target_column (str): Column name for binary target.
        sequence_length (int): Time window for each sequence.
        test_size (float): Proportion of test samples (applied per symbol).

    Returns:
        Tuple of numpy arrays: X_train, X_test, y_train, y_test
    """
    X_train, y_train, X_test, y_test = [], [], [], []

    symbols = df["symbol"].unique()
    for symbol in symbols:
        df_symbol = df[df["symbol"] == symbol].copy()
        df_symbol = df_symbol.sort_values("date")

        if len(df_symbol) <= sequence_length:
            continue  # skip if not enough data

        df_symbol[target_column] = df_symbol[target_column].astype(int)
        features = df_symbol.drop(columns=["date", "symbol", "target_3m", "target_6m", "target_1y"], errors="ignore")
        target = df_symbol[target_column].values

        split_idx = int(len(features) * (1 - test_size))
        for i in range(len(features) - sequence_length):
            if i + sequence_length >= len(features):
                continue  # avoid index error

            X_seq = features.iloc[i:i + sequence_length].values.astype(np.float32)
            y_val = target[i + sequence_length]

            if i + sequence_length < split_idx:
                X_train.append(X_seq)
                y_train.append(y_val)
            else:
                X_test.append(X_seq)
                y_test.append(y_val)

    return (
        np.array(X_train),
        np.array(X_test),
        np.array(y_train),
        np.array(y_test)
    )

# %%
def train_base_lstm_classifier(
    X_train,
    X_test,
    y_train,
    y_test,
    sequence_length=60,
    epochs=30,
    batch_size=32,
    patience=4,
    class_weight=None
):
    """
    Trains a simple LSTM classifier with basic architecture and early stopping.

    Args:
        X_train (np.ndarray): Training sequences.
        X_test (np.ndarray): Test sequences.
        y_train (np.ndarray): Training labels.
        y_test (np.ndarray): Test labels.
        sequence_length (int): Length of each input sequence.
        epochs (int): Maximum number of epochs.
        batch_size (int): Batch size.
        patience (int): Early stopping patience.
        class_weight (dict, optional): Class weights to handle imbalance.

    Returns:
        model (Sequential): Trained Keras model.
        X_test (np.ndarray): Test features.
        y_test (np.ndarray): Test labels.
        y_prob (np.ndarray): Predicted probabilities.
        y_pred (np.ndarray): Predicted binary classes.
    """
    model = Sequential([
        LSTM(32, input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss=BinaryCrossentropy(),
        metrics=['accuracy', AUC(name='auc')]
    )

    early_stop = EarlyStopping(
        monitor='val_auc',
        mode='max',
        patience=patience,
        restore_best_weights=True
    )

    model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop],
        verbose=1,
        class_weight=class_weight
    )

    y_prob = model.predict(X_test).flatten()
    y_pred = (y_prob > 0.5).astype(int)

    return model, X_test, y_test, y_prob, y_pred

# %%
def train_improved_lstm_classifier(
    X_train,
    X_test,
    y_train,
    y_test,
    sequence_length=120,
    epochs=30,
    batch_size=32,
    patience=6,
    learning_rate=1e-4,
    threshold=0.5,
    class_weight=None
):
    """
    Trains a bidirectional LSTM classifier with dropout, batch normalization, and threshold tuning.

    Args:
        X_train, X_test: Input sequences
        y_train, y_test: Labels
        sequence_length (int): Number of timesteps per sequence
        epochs (int): Max epochs
        batch_size (int): Training batch size
        patience (int): Early stopping patience
        learning_rate (float): Optimizer learning rate
        threshold (float): Threshold to binarize output
        class_weight (dict): Optional class weights

    Returns:
        model: Trained Keras model
        X_test, y_test: Evaluation inputs
        y_prob: Predicted probabilities
        y_pred: Binary predictions based on threshold
    """
    model = Sequential([
        Bidirectional(LSTM(64, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
        BatchNormalization(),
        Dropout(0.4),
        Bidirectional(LSTM(32, return_sequences=False)),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=BinaryCrossentropy(),
        metrics=['accuracy', AUC(name='auc'), Precision(name='precision'), Recall(name='recall')]
    )

    early_stop = EarlyStopping(
        monitor='val_auc',
        mode='max',
        patience=patience,
        restore_best_weights=True
    )

    model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop],
        verbose=1,
        class_weight=class_weight
    )

    y_prob = model.predict(X_test).flatten()
    y_pred = (y_prob > threshold).astype(int)

    return model, X_test, y_test, y_prob, y_pred

# %% [markdown]
# # **MAIN**

# %%
with open("config.yaml", "r") as file:
    config = yaml.safe_load(file)

account_name = config['storage']['storage_account_name']
container_name = config['storage']['container_name']
relative_path = config['storage']['relative_path']
access_key = config['storage']['access_key']

# Cargar el DataFrame desde Azure
df_full = load_data_from_dl(account_name, container_name, relative_path, access_key)
df_full = df_full.dropna(subset=['ret_next_3m', 'ret_next_6m', 'ret_next_1y'])

# %%
df_full.to_parquet("df_full_spark.parquet")

# %%
#df_full=pd.read_parquet("df_full_spark.parquet")

# %%
#Addtargets
df_full["target_3m"] = (df_full["ret_next_3m"] > 0.1).astype(int)
df_full["target_6m"] = (df_full["ret_next_6m"] > 0.1).astype(int)
df_full["target_1y"] = (df_full["ret_next_1y"] > 0.1).astype(int)
print(f" target_3m: {df_full['target_3m'].value_counts()}")
print(f" target_6m: {df_full['target_6m'].value_counts()}")
print(f" target_1y: {df_full['target_1y'].value_counts()}")

# %%
# Selección de top 50 y sequence_length = 252 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(50)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])
df_clean.to_csv("1_df_clean_ordenado.csv",sep=";")

print(f" target_3m: {df_clean['target_3m'].value_counts()}")
print(f" target_6m: {df_clean['target_6m'].value_counts()}")
print(f" target_1y: {df_clean['target_1y'].value_counts()}")


# Limpieza con imputación
df_clean = clean_columns(df_clean)

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)


# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 252
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_base_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    class_weight=weight_dict
)

# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
#  target_3m: target_3m
# 0    227663
# 1     84902
# Name: count, dtype: int64
#  target_6m: target_6m
# 0    193544
# 1    119021
# Name: count, dtype: int64
#  target_1y: target_1y
# 0    161096
# 1    151469
# Name: count, dtype: int64
# Shape before: (312565, 56)
# Shape after: (312565, 32)
# df_scaled: (312565, 32)
# columns: Index(['close_v', 'volume', 'prev_close', 'prev_volume', 'daily_return',
#        'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'target_3m', 'target_6m',
#        'target_1y', 'symbol', 'date'],
#       dtype='object')
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 7420/7420 ━━━━━━━━━━━━━━━━━━━━ 110s 14ms/step - accuracy: 0.5078 - auc: 0.5435 - loss: 0.6894 - val_accuracy: 0.5689 - val_auc: 0.5526 - val_loss: 0.6869
# Epoch 2/30
# 7420/7420 ━━━━━━━━━━━━━━━━━━━━ 102s 14ms/step - accuracy: 0.5270 - auc: 0.5646 - loss: 0.6857 - val_accuracy: 0.5495 - val_auc: 0.5644 - val_loss: 0.6860
# Epoch 3/30
# 7420/7420 ━━━━━━━━━━━━━━━━━━━━ 102s 14ms/step - accuracy: 0.5480 - auc: 0.5734 - loss: 0.6834 - val_accuracy: 0.5905 - val_auc: 0.5755 - val_loss: 0.6807
# Epoch 4/30
# 7420/7420 ━━━━━━━━━━━━━━━━━━━━ 102s 14ms/step - accuracy: 0.5384 - auc: 0.5745 - loss: 0.6850 - val_accuracy: 0.6028 - val_auc: 0.5776 - val_loss: 0.6855
# Epoch 5/30
# 7420/7420 ━━━━━━━━━━━━━━━━━━━━ 102s 14ms/step - accuracy: 0.5552 - auc: 0.5849 - loss: 0.6804 - val_accuracy: 0.5495 - val_auc: 0.5957 - val_loss: 0.6876
# Epoch 6/30
# 7420/7420 ━━━━━━━━━━━━━━━━━━━━ 102s 14ms/step - accuracy: 0.5580 - auc: 0.5899 - loss: 0.6788 - val_accuracy: 0.6096 - val_auc: 0.5881 - val_loss: 0.6773
# Epoch 7/30
# 7420/7420 ━━━━━━━━━━━━━━━━━━━━ 102s 14ms/step - accuracy: 0.5528 - auc: 0.5808 - loss: 0.6809 - val_accuracy: 0.6099 - val_auc: 0.5678 - val_loss: 0.6794
# Epoch 8/30
# 7420/7420 ━━━━━━━━━━━━━━━━━━━━ 102s 14ms/step - accuracy: 0.5317 - auc: 0.5650 - loss: 0.6853 - val_accuracy: 0.5823 - val_auc: 0.5737 - val_loss: 0.6867
# Epoch 9/30
# 7420/7420 ━━━━━━━━━━━━━━━━━━━━ 102s 14ms/step - accuracy: 0.5192 - auc: 0.5699 - loss: 0.6844 - val_accuracy: 0.5276 - val_auc: 0.5755 - val_loss: 0.6920
# 1955/1955 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step
# Accuracy: 0.5495
# F1 Score: 0.5340
# ROC AUC: 0.5958
# Confusion Matrix:
# [[18220 17800]
#  [10375 16142]]
# Precision: 0.4756
# Recall: 0.6087
# (0.549466715704303,
#  0.5339817066110918,
#  np.float64(0.5957903928748463),
#  array([[18220, 17800],
#         [10375, 16142]]),
#  0.4755759825584821,
#  0.6087415620168194)

# %%
# Selección de top 20 y sequence_length = 500 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(20)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])
df_clean.to_csv("1_df_clean_ordenado.csv",sep=";")

print(f" target_3m: {df_clean['target_3m'].value_counts()}")
print(f" target_6m: {df_clean['target_6m'].value_counts()}")
print(f" target_1y: {df_clean['target_1y'].value_counts()}")


# Limpieza con imputación
df_clean = clean_columns(df_clean)

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)


# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 500
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_base_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    class_weight=weight_dict
)

# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
#  target_3m: target_3m
# 0    88490
# 1    36976
# Name: count, dtype: int64
#  target_6m: target_6m
# 0    74458
# 1    51008
# Name: count, dtype: int64
#  target_1y: target_1y
# 1    63307
# 0    62159
# Name: count, dtype: int64
# Shape before: (125466, 56)
# Shape after: (125466, 32)
# df_scaled: (125466, 32)
# columns: Index(['close_v', 'volume', 'prev_close', 'prev_volume', 'daily_return',
#        'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'target_3m', 'target_6m',
#        'target_1y', 'symbol', 'date'],
#       dtype='object')
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 68s 23ms/step - accuracy: 0.5165 - auc: 0.5347 - loss: 0.6905 - val_accuracy: 0.5228 - val_auc: 0.4841 - val_loss: 0.6948
# Epoch 2/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5587 - auc: 0.5690 - loss: 0.6859 - val_accuracy: 0.5331 - val_auc: 0.4835 - val_loss: 0.7241
# Epoch 3/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5348 - auc: 0.5491 - loss: 0.6897 - val_accuracy: 0.5120 - val_auc: 0.4740 - val_loss: 0.6980
# Epoch 4/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 65s 23ms/step - accuracy: 0.5423 - auc: 0.5706 - loss: 0.6850 - val_accuracy: 0.5557 - val_auc: 0.4991 - val_loss: 0.6893
# Epoch 5/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 22ms/step - accuracy: 0.5377 - auc: 0.5552 - loss: 0.6875 - val_accuracy: 0.5342 - val_auc: 0.5075 - val_loss: 0.6939
# Epoch 6/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5689 - auc: 0.5843 - loss: 0.6813 - val_accuracy: 0.5370 - val_auc: 0.4955 - val_loss: 0.6987
# Epoch 7/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5723 - auc: 0.5800 - loss: 0.6828 - val_accuracy: 0.4580 - val_auc: 0.5338 - val_loss: 0.6962
# Epoch 8/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5317 - auc: 0.5422 - loss: 0.6890 - val_accuracy: 0.5453 - val_auc: 0.5126 - val_loss: 0.6877
# Epoch 9/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5866 - auc: 0.5917 - loss: 0.6787 - val_accuracy: 0.5418 - val_auc: 0.5062 - val_loss: 0.7018
# Epoch 10/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5610 - auc: 0.5799 - loss: 0.6802 - val_accuracy: 0.5833 - val_auc: 0.5579 - val_loss: 0.7028
# Epoch 11/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5881 - auc: 0.5913 - loss: 0.6787 - val_accuracy: 0.5498 - val_auc: 0.5335 - val_loss: 0.7127
# Epoch 12/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5925 - auc: 0.6031 - loss: 0.6741 - val_accuracy: 0.5373 - val_auc: 0.5179 - val_loss: 0.7007
# Epoch 13/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5741 - auc: 0.5867 - loss: 0.6785 - val_accuracy: 0.5455 - val_auc: 0.5443 - val_loss: 0.7351
# Epoch 14/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5682 - auc: 0.5946 - loss: 0.6759 - val_accuracy: 0.5739 - val_auc: 0.5742 - val_loss: 0.7248
# Epoch 15/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5678 - auc: 0.5926 - loss: 0.6779 - val_accuracy: 0.5759 - val_auc: 0.5711 - val_loss: 0.6998
# Epoch 16/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5796 - auc: 0.5960 - loss: 0.6761 - val_accuracy: 0.5541 - val_auc: 0.5624 - val_loss: 0.7240
# Epoch 17/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5878 - auc: 0.5982 - loss: 0.6746 - val_accuracy: 0.5700 - val_auc: 0.5645 - val_loss: 0.7185
# Epoch 18/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 64s 23ms/step - accuracy: 0.5719 - auc: 0.5935 - loss: 0.6755 - val_accuracy: 0.5537 - val_auc: 0.5387 - val_loss: 0.7294
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step
# Accuracy: 0.5739
# F1 Score: 0.4932
# ROC AUC: 0.5744
# Confusion Matrix:
# [[9200 4784]
#  [5912 5204]]
# Precision: 0.5210
# Recall: 0.4682
# (0.5738645418326693,
#  0.4931766489764973,
#  np.float64(0.5743835337594478),
#  array([[9200, 4784],
#         [5912, 5204]]),
#  0.5210252302763316,
#  0.4681540122346168)

# %%
# Selección de top 50 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(20)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])

# Limpieza con imputación
df_clean = clean_columns(df_clean)

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)

# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 60
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_improved_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    class_weight=weight_dict
)

# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
# Shape before: (312565, 56)
# Shape after: (312565, 32)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 173s 21ms/step - accuracy: 0.5211 - auc: 0.5116 - loss: 0.7918 - precision: 0.3773 - recall: 0.4551 - val_accuracy: 0.5248 - val_auc: 0.5633 - val_loss: 0.6873 - val_precision: 0.4562 - val_recall: 0.6277
# Epoch 2/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 164s 21ms/step - accuracy: 0.5128 - auc: 0.5292 - loss: 0.6996 - precision: 0.3883 - recall: 0.5453 - val_accuracy: 0.4953 - val_auc: 0.5550 - val_loss: 0.6981 - val_precision: 0.4434 - val_recall: 0.7453
# Epoch 3/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 159s 21ms/step - accuracy: 0.5252 - auc: 0.5520 - loss: 0.6889 - precision: 0.4000 - recall: 0.5753 - val_accuracy: 0.5757 - val_auc: 0.5734 - val_loss: 0.6796 - val_precision: 0.4996 - val_recall: 0.4525
# Epoch 4/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5327 - auc: 0.5695 - loss: 0.6855 - precision: 0.4115 - recall: 0.6106 - val_accuracy: 0.4645 - val_auc: 0.5413 - val_loss: 0.6997 - val_precision: 0.4292 - val_recall: 0.7965
# Epoch 5/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5421 - auc: 0.5826 - loss: 0.6810 - precision: 0.4177 - recall: 0.6165 - val_accuracy: 0.6054 - val_auc: 0.5909 - val_loss: 0.6800 - val_precision: 0.5462 - val_recall: 0.4093
# Epoch 6/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 155s 20ms/step - accuracy: 0.5447 - auc: 0.5937 - loss: 0.6779 - precision: 0.4248 - recall: 0.6544 - val_accuracy: 0.5624 - val_auc: 0.5792 - val_loss: 0.6891 - val_precision: 0.4854 - val_recall: 0.5292
# Epoch 7/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 155s 20ms/step - accuracy: 0.5517 - auc: 0.6049 - loss: 0.6740 - precision: 0.4302 - recall: 0.6590 - val_accuracy: 0.5414 - val_auc: 0.5442 - val_loss: 0.6960 - val_precision: 0.4649 - val_recall: 0.5405
# Epoch 8/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 155s 20ms/step - accuracy: 0.5601 - auc: 0.6139 - loss: 0.6702 - precision: 0.4341 - recall: 0.6558 - val_accuracy: 0.4486 - val_auc: 0.5300 - val_loss: 0.7253 - val_precision: 0.4247 - val_recall: 0.8463
# Epoch 9/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5667 - auc: 0.6239 - loss: 0.6674 - precision: 0.4422 - recall: 0.6653 - val_accuracy: 0.5927 - val_auc: 0.5685 - val_loss: 0.6864 - val_precision: 0.5373 - val_recall: 0.2835
# Epoch 10/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 155s 20ms/step - accuracy: 0.5768 - auc: 0.6342 - loss: 0.6622 - precision: 0.4489 - recall: 0.6630 - val_accuracy: 0.5075 - val_auc: 0.5082 - val_loss: 0.7075 - val_precision: 0.4311 - val_recall: 0.5050
# Epoch 11/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5859 - auc: 0.6455 - loss: 0.6570 - precision: 0.4572 - recall: 0.6673 - val_accuracy: 0.5275 - val_auc: 0.5461 - val_loss: 0.7045 - val_precision: 0.4534 - val_recall: 0.5563
# 1955/1955 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step
# Accuracy: 0.6054
# F1 Score: 0.4679
# ROC AUC: 0.5909
# Confusion Matrix:
# [[27004  9016]
#  [15664 10853]]
# Precision: 0.5462
# Recall: 0.4093
# (0.6053536306506548,
#  0.46794291381020137,
#  np.float64(0.590943910517044),
#  array([[27004,  9016],
#         [15664, 10853]]),
#  0.5462277920378479,
#  0.4092846098729117)

# %%
# Selección de top 50 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(50)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])


# Limpieza con imputación
df_clean = clean_columns(df_clean)

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)


# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 120
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_improved_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    class_weight=weight_dict
)

# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
# Shape before: (312565, 56)
# Shape after: (312565, 32)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 238s 30ms/step - accuracy: 0.5054 - auc: 0.5144 - loss: 0.7696 - precision: 0.3796 - recall: 0.5264 - val_accuracy: 0.4990 - val_auc: 0.5550 - val_loss: 0.6976 - val_precision: 0.4451 - val_recall: 0.7356
# Epoch 2/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 231s 30ms/step - accuracy: 0.5181 - auc: 0.5373 - loss: 0.6965 - precision: 0.3920 - recall: 0.5514 - val_accuracy: 0.6066 - val_auc: 0.5803 - val_loss: 0.6718 - val_precision: 0.6296 - val_recall: 0.1754
# Epoch 3/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 230s 30ms/step - accuracy: 0.5310 - auc: 0.5575 - loss: 0.6873 - precision: 0.4036 - recall: 0.5782 - val_accuracy: 0.4692 - val_auc: 0.5608 - val_loss: 0.6971 - val_precision: 0.4347 - val_recall: 0.8379
# Epoch 4/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 229s 30ms/step - accuracy: 0.5311 - auc: 0.5752 - loss: 0.6835 - precision: 0.4127 - recall: 0.6299 - val_accuracy: 0.5947 - val_auc: 0.5783 - val_loss: 0.6801 - val_precision: 0.5313 - val_recall: 0.3737
# Epoch 5/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 229s 30ms/step - accuracy: 0.5497 - auc: 0.5901 - loss: 0.6791 - precision: 0.4237 - recall: 0.6114 - val_accuracy: 0.6048 - val_auc: 0.5822 - val_loss: 0.6818 - val_precision: 0.5500 - val_recall: 0.3732
# Epoch 6/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 230s 30ms/step - accuracy: 0.5620 - auc: 0.6075 - loss: 0.6737 - precision: 0.4353 - recall: 0.6266 - val_accuracy: 0.5557 - val_auc: 0.5352 - val_loss: 0.6974 - val_precision: 0.4682 - val_recall: 0.3512
# Epoch 7/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 228s 30ms/step - accuracy: 0.5733 - auc: 0.6244 - loss: 0.6673 - precision: 0.4444 - recall: 0.6435 - val_accuracy: 0.5408 - val_auc: 0.5500 - val_loss: 0.7015 - val_precision: 0.4618 - val_recall: 0.5002
# Epoch 8/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 228s 30ms/step - accuracy: 0.5842 - auc: 0.6412 - loss: 0.6599 - precision: 0.4555 - recall: 0.6615 - val_accuracy: 0.6076 - val_auc: 0.5944 - val_loss: 0.6748 - val_precision: 0.5682 - val_recall: 0.3101
# Epoch 9/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 228s 30ms/step - accuracy: 0.5989 - auc: 0.6554 - loss: 0.6529 - precision: 0.4694 - recall: 0.6680 - val_accuracy: 0.4427 - val_auc: 0.5254 - val_loss: 0.7429 - val_precision: 0.4170 - val_recall: 0.7900
# Epoch 10/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 229s 30ms/step - accuracy: 0.6101 - auc: 0.6732 - loss: 0.6436 - precision: 0.4815 - recall: 0.6831 - val_accuracy: 0.5686 - val_auc: 0.5651 - val_loss: 0.7223 - val_precision: 0.4887 - val_recall: 0.3755
# Epoch 11/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 229s 30ms/step - accuracy: 0.6238 - auc: 0.6899 - loss: 0.6341 - precision: 0.4941 - recall: 0.6890 - val_accuracy: 0.5593 - val_auc: 0.5390 - val_loss: 0.7367 - val_precision: 0.4757 - val_recall: 0.3842
# Epoch 12/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 229s 30ms/step - accuracy: 0.6387 - auc: 0.7058 - loss: 0.6234 - precision: 0.5069 - recall: 0.6973 - val_accuracy: 0.4844 - val_auc: 0.5270 - val_loss: 0.7749 - val_precision: 0.4268 - val_recall: 0.6300
# Epoch 13/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 229s 30ms/step - accuracy: 0.6503 - auc: 0.7212 - loss: 0.6124 - precision: 0.5192 - recall: 0.7026 - val_accuracy: 0.5720 - val_auc: 0.5596 - val_loss: 0.7715 - val_precision: 0.4944 - val_recall: 0.4171
# Epoch 14/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 221s 29ms/step - accuracy: 0.6615 - auc: 0.7328 - loss: 0.6035 - precision: 0.5306 - recall: 0.7081 - val_accuracy: 0.5736 - val_auc: 0.5652 - val_loss: 0.7753 - val_precision: 0.4968 - val_recall: 0.4305
# 1955/1955 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step
# Accuracy: 0.6076
# F1 Score: 0.4013
# ROC AUC: 0.5943
# Confusion Matrix:
# [[29771  6249]
#  [18293  8224]]
# Precision: 0.5682
# Recall: 0.3101
# (0.6075603242880215,
#  0.4012686020980727,
#  np.float64(0.5943450370967744),
#  array([[29771,  6249],
#         [18293,  8224]]),
#  0.5682304981690044,
#  0.3101406644793906)

# %%
# Selección de top 20 símbolos con más histórico y sequence_length = 500
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(20)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])


# Limpieza con imputación
df_clean = clean_columns(df_clean)

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)


# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 500
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_improved_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    class_weight=weight_dict
)

# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
# Shape before: (125466, 56)
# Shape after: (125466, 32)
# df_scaled: (125466, 32)
# columns: Index(['close_v', 'volume', 'prev_close', 'prev_volume', 'daily_return',
#        'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'target_3m', 'target_6m',
#        'target_1y', 'symbol', 'date'],
#       dtype='object')
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 239s 82ms/step - accuracy: 0.5156 - auc: 0.5080 - loss: 0.8390 - precision: 0.4220 - recall: 0.4376 - val_accuracy: 0.4848 - val_auc: 0.4894 - val_loss: 0.7103 - val_precision: 0.4360 - val_recall: 0.5565
# Epoch 2/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.5105 - auc: 0.5192 - loss: 0.7291 - precision: 0.4274 - recall: 0.5228 - val_accuracy: 0.4916 - val_auc: 0.4847 - val_loss: 0.7058 - val_precision: 0.4206 - val_recall: 0.3918
# Epoch 3/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.5220 - auc: 0.5340 - loss: 0.7041 - precision: 0.4366 - recall: 0.5277 - val_accuracy: 0.5571 - val_auc: 0.5457 - val_loss: 0.6844 - val_precision: 0.5000 - val_recall: 0.2092
# Epoch 4/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.5361 - auc: 0.5521 - loss: 0.6940 - precision: 0.4499 - recall: 0.5391 - val_accuracy: 0.5543 - val_auc: 0.5219 - val_loss: 0.6895 - val_precision: 0.4909 - val_recall: 0.1745
# Epoch 5/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.5505 - auc: 0.5753 - loss: 0.6854 - precision: 0.4669 - recall: 0.5721 - val_accuracy: 0.4660 - val_auc: 0.5116 - val_loss: 0.7377 - val_precision: 0.4375 - val_recall: 0.7201
# Epoch 6/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.5703 - auc: 0.5998 - loss: 0.6770 - precision: 0.4850 - recall: 0.5643 - val_accuracy: 0.5447 - val_auc: 0.5527 - val_loss: 0.7067 - val_precision: 0.4830 - val_recall: 0.4010
# Epoch 7/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.5825 - auc: 0.6162 - loss: 0.6715 - precision: 0.4991 - recall: 0.5824 - val_accuracy: 0.5569 - val_auc: 0.5501 - val_loss: 0.7284 - val_precision: 0.4993 - val_recall: 0.1608
# Epoch 8/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.5993 - auc: 0.6411 - loss: 0.6613 - precision: 0.5149 - recall: 0.5982 - val_accuracy: 0.5606 - val_auc: 0.5511 - val_loss: 0.7303 - val_precision: 0.5062 - val_recall: 0.3176
# Epoch 9/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.6062 - auc: 0.6482 - loss: 0.6575 - precision: 0.5213 - recall: 0.5962 - val_accuracy: 0.5087 - val_auc: 0.5149 - val_loss: 0.7450 - val_precision: 0.4483 - val_recall: 0.4742
# Epoch 10/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.6251 - auc: 0.6719 - loss: 0.6465 - precision: 0.5407 - recall: 0.6258 - val_accuracy: 0.5430 - val_auc: 0.5425 - val_loss: 0.7418 - val_precision: 0.4794 - val_recall: 0.3698
# Epoch 11/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 233s 82ms/step - accuracy: 0.6412 - auc: 0.6928 - loss: 0.6342 - precision: 0.5573 - recall: 0.6400 - val_accuracy: 0.5415 - val_auc: 0.5222 - val_loss: 0.7453 - val_precision: 0.4807 - val_recall: 0.4392
# Epoch 12/30
# 2824/2824 ━━━━━━━━━━━━━━━━━━━━ 227s 80ms/step - accuracy: 0.6530 - auc: 0.7067 - loss: 0.6265 - precision: 0.5748 - recall: 0.6513 - val_accuracy: 0.5174 - val_auc: 0.5206 - val_loss: 0.7679 - val_precision: 0.4618 - val_recall: 0.5426
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 24s 30ms/step
# Accuracy: 0.5447
# F1 Score: 0.4382
# ROC AUC: 0.5527
# Confusion Matrix:
# [[9213 4771]
#  [6658 4458]]
# Precision: 0.4830
# Recall: 0.4010
# (0.5446613545816733,
#  0.43824035389530597,
#  np.float64(0.552652895011664),
#  array([[9213, 4771],
#         [6658, 4458]]),
#  0.4830425831617727,
#  0.40104354084202953)

# %% [markdown]
# #Modificando la probabilidad a 0.4 para aumenta recall train_improved_lstm_classifier

# %%
# Selección de top 50 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(50)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])


# Limpieza con imputación
df_clean = clean_columns(df_clean)

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)

# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 60
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_improved_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    epochs=30,
    batch_size=32,
    patience=6,
    learning_rate=1e-4,
    threshold=0.4,
    class_weight=weight_dict
)


# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
# Shape before: (312565, 56)
# Shape after: (312565, 32)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 162s 20ms/step - accuracy: 0.5064 - auc: 0.5134 - loss: 0.7709 - precision: 0.3780 - recall: 0.5237 - val_accuracy: 0.5013 - val_auc: 0.5554 - val_loss: 0.7014 - val_precision: 0.4465 - val_recall: 0.7343
# Epoch 2/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 155s 20ms/step - accuracy: 0.5188 - auc: 0.5358 - loss: 0.6968 - precision: 0.3924 - recall: 0.5459 - val_accuracy: 0.5653 - val_auc: 0.5571 - val_loss: 0.6835 - val_precision: 0.4833 - val_recall: 0.3647
# Epoch 3/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5297 - auc: 0.5530 - loss: 0.6889 - precision: 0.4027 - recall: 0.5662 - val_accuracy: 0.4860 - val_auc: 0.5228 - val_loss: 0.7026 - val_precision: 0.4403 - val_recall: 0.7826
# Epoch 4/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.5384 - auc: 0.5781 - loss: 0.6827 - precision: 0.4158 - recall: 0.6271 - val_accuracy: 0.4724 - val_auc: 0.5094 - val_loss: 0.7085 - val_precision: 0.4345 - val_recall: 0.8100
# Epoch 5/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 158s 21ms/step - accuracy: 0.5362 - auc: 0.5844 - loss: 0.6803 - precision: 0.4171 - recall: 0.6509 - val_accuracy: 0.5557 - val_auc: 0.4939 - val_loss: 0.6955 - val_precision: 0.4506 - val_recall: 0.2180
# Epoch 6/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.5414 - auc: 0.5953 - loss: 0.6780 - precision: 0.4250 - recall: 0.6752 - val_accuracy: 0.5472 - val_auc: 0.5771 - val_loss: 0.6853 - val_precision: 0.4715 - val_recall: 0.5613
# Epoch 7/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 160s 21ms/step - accuracy: 0.5453 - auc: 0.6020 - loss: 0.6755 - precision: 0.4288 - recall: 0.6845 - val_accuracy: 0.5407 - val_auc: 0.5349 - val_loss: 0.6933 - val_precision: 0.4593 - val_recall: 0.4695
# Epoch 8/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 164s 21ms/step - accuracy: 0.5550 - auc: 0.6100 - loss: 0.6722 - precision: 0.4336 - recall: 0.6782 - val_accuracy: 0.5666 - val_auc: 0.5635 - val_loss: 0.6917 - val_precision: 0.4880 - val_recall: 0.4472
# Epoch 9/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 167s 22ms/step - accuracy: 0.5602 - auc: 0.6186 - loss: 0.6696 - precision: 0.4395 - recall: 0.6858 - val_accuracy: 0.4907 - val_auc: 0.5512 - val_loss: 0.7104 - val_precision: 0.4404 - val_recall: 0.7442
# Epoch 10/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 166s 21ms/step - accuracy: 0.5671 - auc: 0.6291 - loss: 0.6652 - precision: 0.4447 - recall: 0.6854 - val_accuracy: 0.4266 - val_auc: 0.4622 - val_loss: 0.7610 - val_precision: 0.4173 - val_recall: 0.8879
# Epoch 11/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 166s 21ms/step - accuracy: 0.5742 - auc: 0.6373 - loss: 0.6616 - precision: 0.4505 - recall: 0.6874 - val_accuracy: 0.5866 - val_auc: 0.5527 - val_loss: 0.6933 - val_precision: 0.5235 - val_recall: 0.2786
# Epoch 12/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 166s 21ms/step - accuracy: 0.5835 - auc: 0.6465 - loss: 0.6574 - precision: 0.4583 - recall: 0.6896 - val_accuracy: 0.4366 - val_auc: 0.4988 - val_loss: 0.7693 - val_precision: 0.4207 - val_recall: 0.8725
# 1955/1955 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step
# Accuracy: 0.4786
# F1 Score: 0.5743
# ROC AUC: 0.5773
# Confusion Matrix:
# [[ 7935 28085]
#  [ 4523 21994]]
# Precision: 0.4392
# Recall: 0.8294
# (0.4785806802372995,
#  0.5742858634915662,
#  np.float64(0.5772807626766917),
#  array([[ 7935, 28085],
#         [ 4523, 21994]]),
#  0.43918608598414505,
#  0.8294301768676698)

# %%
# Selección de top 50 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(50)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])


# Limpieza con imputación
df_clean = clean_columns(df_clean)

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)

# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 120
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_improved_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    epochs=30,
    batch_size=32,
    patience=6,
    learning_rate=1e-4,
    threshold=0.4,
    class_weight=weight_dict
)


# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
# Shape before: (312565, 56)
# Shape after: (312565, 32)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 236s 30ms/step - accuracy: 0.5067 - auc: 0.5116 - loss: 0.7767 - precision: 0.3757 - recall: 0.5089 - val_accuracy: 0.5712 - val_auc: 0.5739 - val_loss: 0.6868 - val_precision: 0.4944 - val_recall: 0.4962
# Epoch 2/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 230s 30ms/step - accuracy: 0.5118 - auc: 0.5290 - loss: 0.6985 - precision: 0.3884 - recall: 0.5512 - val_accuracy: 0.4908 - val_auc: 0.5755 - val_loss: 0.6952 - val_precision: 0.4424 - val_recall: 0.7718
# Epoch 3/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 230s 30ms/step - accuracy: 0.5287 - auc: 0.5600 - loss: 0.6870 - precision: 0.4042 - recall: 0.5914 - val_accuracy: 0.6030 - val_auc: 0.5908 - val_loss: 0.6715 - val_precision: 0.5466 - val_recall: 0.3746
# Epoch 4/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 231s 30ms/step - accuracy: 0.5378 - auc: 0.5765 - loss: 0.6825 - precision: 0.4133 - recall: 0.6069 - val_accuracy: 0.5037 - val_auc: 0.5308 - val_loss: 0.7018 - val_precision: 0.4408 - val_recall: 0.6346
# Epoch 5/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 232s 30ms/step - accuracy: 0.5489 - auc: 0.5919 - loss: 0.6789 - precision: 0.4246 - recall: 0.6266 - val_accuracy: 0.5904 - val_auc: 0.5835 - val_loss: 0.6834 - val_precision: 0.6489 - val_recall: 0.0740
# Epoch 6/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 232s 30ms/step - accuracy: 0.5547 - auc: 0.6025 - loss: 0.6762 - precision: 0.4327 - recall: 0.6407 - val_accuracy: 0.5643 - val_auc: 0.5371 - val_loss: 0.6894 - val_precision: 0.4818 - val_recall: 0.3649
# Epoch 7/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 231s 30ms/step - accuracy: 0.5658 - auc: 0.6153 - loss: 0.6715 - precision: 0.4410 - recall: 0.6430 - val_accuracy: 0.5725 - val_auc: 0.5294 - val_loss: 0.7014 - val_precision: 0.4925 - val_recall: 0.2701
# Epoch 8/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 231s 30ms/step - accuracy: 0.5747 - auc: 0.6285 - loss: 0.6663 - precision: 0.4496 - recall: 0.6597 - val_accuracy: 0.4658 - val_auc: 0.4907 - val_loss: 0.7300 - val_precision: 0.4097 - val_recall: 0.5900
# Epoch 9/30
# 7626/7626 ━━━━━━━━━━━━━━━━━━━━ 231s 30ms/step - accuracy: 0.5884 - auc: 0.6454 - loss: 0.6586 - precision: 0.4604 - recall: 0.6640 - val_accuracy: 0.4779 - val_auc: 0.5191 - val_loss: 0.7334 - val_precision: 0.4255 - val_recall: 0.6609
# 1955/1955 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step
# Accuracy: 0.4789
# F1 Score: 0.5692
# ROC AUC: 0.5909
# Confusion Matrix:
# [[ 8413 27607]
#  [ 4984 21533]]
# Precision: 0.4382
# Recall: 0.8120
# (0.4788525193085693,
#  0.5692269056399276,
#  np.float64(0.5908532701000356),
#  array([[ 8413, 27607],
#         [ 4984, 21533]]),
#  0.4381969881969882,
#  0.812045103141381)

# %% [markdown]
# #Modificando los targets a  0.05 y 0.01

# %%
#Addtargets
df_full["target_3m"] = (df_full["ret_next_3m"] > 0.05).astype(int)
df_full["target_6m"] = (df_full["ret_next_6m"] > 0.05).astype(int)
df_full["target_1y"] = (df_full["ret_next_1y"] > 0.05).astype(int)

# Selección de top 50 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(50)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])


# Limpieza con imputación
df_clean = clean_columns(df_clean)

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)

# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 60
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_improved_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    epochs=30,
    batch_size=32,
    patience=6,
    learning_rate=1e-4,
    threshold=0.5,
    class_weight=weight_dict
)


# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
# Shape before: (312565, 56)
# Shape after: (312565, 32)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 163s 20ms/step - accuracy: 0.5049 - auc: 0.5091 - loss: 0.7706 - precision: 0.4864 - recall: 0.5290 - val_accuracy: 0.5137 - val_auc: 0.5047 - val_loss: 0.7021 - val_precision: 0.5290 - val_recall: 0.5878
# Epoch 2/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 160s 21ms/step - accuracy: 0.5172 - auc: 0.5261 - loss: 0.6973 - precision: 0.4967 - recall: 0.5278 - val_accuracy: 0.5043 - val_auc: 0.5234 - val_loss: 0.6995 - val_precision: 0.5342 - val_recall: 0.3626
# Epoch 3/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.5388 - auc: 0.5554 - loss: 0.6889 - precision: 0.5187 - recall: 0.5398 - val_accuracy: 0.4977 - val_auc: 0.5327 - val_loss: 0.7030 - val_precision: 0.5692 - val_recall: 0.1393
# Epoch 4/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 162s 21ms/step - accuracy: 0.5498 - auc: 0.5716 - loss: 0.6853 - precision: 0.5297 - recall: 0.5742 - val_accuracy: 0.4789 - val_auc: 0.5034 - val_loss: 0.7092 - val_precision: 0.4982 - val_recall: 0.3239
# Epoch 5/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 159s 21ms/step - accuracy: 0.5554 - auc: 0.5806 - loss: 0.6825 - precision: 0.5312 - recall: 0.6292 - val_accuracy: 0.4903 - val_auc: 0.4725 - val_loss: 0.7081 - val_precision: 0.5075 - val_recall: 0.6600
# Epoch 6/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.5602 - auc: 0.5910 - loss: 0.6792 - precision: 0.5327 - recall: 0.6500 - val_accuracy: 0.5278 - val_auc: 0.5374 - val_loss: 0.7085 - val_precision: 0.5949 - val_recall: 0.2876
# Epoch 7/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.5672 - auc: 0.5991 - loss: 0.6764 - precision: 0.5406 - recall: 0.6457 - val_accuracy: 0.5261 - val_auc: 0.5362 - val_loss: 0.7138 - val_precision: 0.5717 - val_recall: 0.3526
# Epoch 8/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.5729 - auc: 0.6066 - loss: 0.6742 - precision: 0.5458 - recall: 0.6416 - val_accuracy: 0.4968 - val_auc: 0.4714 - val_loss: 0.7110 - val_precision: 0.5112 - val_recall: 0.7358
# Epoch 9/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.5766 - auc: 0.6140 - loss: 0.6712 - precision: 0.5507 - recall: 0.6470 - val_accuracy: 0.5281 - val_auc: 0.5416 - val_loss: 0.7336 - val_precision: 0.6139 - val_recall: 0.2489
# Epoch 10/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5834 - auc: 0.6229 - loss: 0.6678 - precision: 0.5562 - recall: 0.6535 - val_accuracy: 0.5276 - val_auc: 0.5425 - val_loss: 0.7185 - val_precision: 0.5724 - val_recall: 0.3613
# Epoch 11/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.5922 - auc: 0.6342 - loss: 0.6629 - precision: 0.5636 - recall: 0.6532 - val_accuracy: 0.5106 - val_auc: 0.5114 - val_loss: 0.7194 - val_precision: 0.5353 - val_recall: 0.4434
# Epoch 12/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5977 - auc: 0.6421 - loss: 0.6591 - precision: 0.5701 - recall: 0.6495 - val_accuracy: 0.5333 - val_auc: 0.5461 - val_loss: 0.7184 - val_precision: 0.5835 - val_recall: 0.3577
# Epoch 13/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.6071 - auc: 0.6550 - loss: 0.6533 - precision: 0.5793 - recall: 0.6593 - val_accuracy: 0.5025 - val_auc: 0.5235 - val_loss: 0.7770 - val_precision: 0.5647 - val_recall: 0.1879
# Epoch 14/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.6139 - auc: 0.6638 - loss: 0.6487 - precision: 0.5861 - recall: 0.6557 - val_accuracy: 0.4958 - val_auc: 0.4929 - val_loss: 0.7537 - val_precision: 0.5163 - val_recall: 0.4781
# Epoch 15/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.6255 - auc: 0.6780 - loss: 0.6415 - precision: 0.6001 - recall: 0.6710 - val_accuracy: 0.5082 - val_auc: 0.5100 - val_loss: 0.7451 - val_precision: 0.5253 - val_recall: 0.5606
# Epoch 16/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.6366 - auc: 0.6891 - loss: 0.6355 - precision: 0.6104 - recall: 0.6659 - val_accuracy: 0.5036 - val_auc: 0.4984 - val_loss: 0.7532 - val_precision: 0.5199 - val_recall: 0.5881
# Epoch 17/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.6427 - auc: 0.7000 - loss: 0.6278 - precision: 0.6164 - recall: 0.6724 - val_accuracy: 0.5052 - val_auc: 0.5043 - val_loss: 0.7506 - val_precision: 0.5269 - val_recall: 0.4725
# Epoch 18/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.6530 - auc: 0.7113 - loss: 0.6206 - precision: 0.6279 - recall: 0.6796 - val_accuracy: 0.5182 - val_auc: 0.5257 - val_loss: 0.7859 - val_precision: 0.5426 - val_recall: 0.4663
# 1955/1955 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step
# Accuracy: 0.5278
# F1 Score: 0.6022
# ROC AUC: 0.5461
# Confusion Matrix:
# [[10660 19366]
#  [10161 22350]]
# Precision: 0.5358
# Recall: 0.6875
# (0.5278475142715512,
#  0.6022067441766473,
#  np.float64(0.5460949658789046),
#  array([[10660, 19366],
#         [10161, 22350]]),
#  0.5357656534662959,
#  0.6874596290486297)

# %%
#Addtargets
df_full["target_3m"] = (df_full["ret_next_3m"] > 0.01).astype(int)
df_full["target_6m"] = (df_full["ret_next_6m"] > 0.01).astype(int)
df_full["target_1y"] = (df_full["ret_next_1y"] > 0.01).astype(int)

# Selección de top 50 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(50)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])


# Limpieza con imputación
df_clean = clean_columns(df_clean)
feature_cols = df_clean.columns.tolist()
joblib.dump(feature_cols, "pkls/feature_columns.pkl")


# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)

# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 60
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_improved_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    epochs=30,
    batch_size=32,
    patience=6,
    learning_rate=1e-4,
    threshold=0.5,
    class_weight=weight_dict
)


# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
# Shape before: (312565, 56)
# Shape after: (312565, 32)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 163s 20ms/step - accuracy: 0.5183 - auc: 0.5179 - loss: 0.7649 - precision: 0.5842 - recall: 0.5429 - val_accuracy: 0.4246 - val_auc: 0.4986 - val_loss: 0.7148 - val_precision: 0.5716 - val_recall: 0.1636
# Epoch 2/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.5374 - auc: 0.5535 - loss: 0.6922 - precision: 0.6086 - recall: 0.5275 - val_accuracy: 0.5077 - val_auc: 0.4457 - val_loss: 0.7031 - val_precision: 0.5730 - val_recall: 0.7047
# Epoch 3/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.5536 - auc: 0.5766 - loss: 0.6845 - precision: 0.6255 - recall: 0.5405 - val_accuracy: 0.4365 - val_auc: 0.4835 - val_loss: 0.7212 - val_precision: 0.5527 - val_recall: 0.3185
# Epoch 4/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 157s 20ms/step - accuracy: 0.5598 - auc: 0.5874 - loss: 0.6812 - precision: 0.6331 - recall: 0.5429 - val_accuracy: 0.5134 - val_auc: 0.4504 - val_loss: 0.7086 - val_precision: 0.5788 - val_recall: 0.6943
# Epoch 5/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5671 - auc: 0.5979 - loss: 0.6778 - precision: 0.6393 - recall: 0.5551 - val_accuracy: 0.5001 - val_auc: 0.4616 - val_loss: 0.7088 - val_precision: 0.5788 - val_recall: 0.6128
# Epoch 6/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5727 - auc: 0.6081 - loss: 0.6747 - precision: 0.6474 - recall: 0.5494 - val_accuracy: 0.4258 - val_auc: 0.5463 - val_loss: 0.7959 - val_precision: 0.7876 - val_recall: 0.0587
# Epoch 7/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5804 - auc: 0.6185 - loss: 0.6704 - precision: 0.6522 - recall: 0.5644 - val_accuracy: 0.4775 - val_auc: 0.5333 - val_loss: 0.7248 - val_precision: 0.6467 - val_recall: 0.2847
# Epoch 8/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5868 - auc: 0.6290 - loss: 0.6668 - precision: 0.6578 - recall: 0.5662 - val_accuracy: 0.5115 - val_auc: 0.4660 - val_loss: 0.7287 - val_precision: 0.5890 - val_recall: 0.6147
# Epoch 9/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.5925 - auc: 0.6345 - loss: 0.6635 - precision: 0.6623 - recall: 0.5849 - val_accuracy: 0.4457 - val_auc: 0.4904 - val_loss: 0.7398 - val_precision: 0.5856 - val_recall: 0.2606
# Epoch 10/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.6002 - auc: 0.6472 - loss: 0.6574 - precision: 0.6712 - recall: 0.5870 - val_accuracy: 0.4544 - val_auc: 0.5088 - val_loss: 0.7527 - val_precision: 0.6098 - val_recall: 0.2517
# Epoch 11/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 158s 20ms/step - accuracy: 0.6099 - auc: 0.6570 - loss: 0.6525 - precision: 0.6773 - recall: 0.6077 - val_accuracy: 0.4461 - val_auc: 0.4804 - val_loss: 0.7561 - val_precision: 0.5704 - val_recall: 0.3107
# Epoch 12/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 156s 20ms/step - accuracy: 0.6128 - auc: 0.6659 - loss: 0.6477 - precision: 0.6820 - recall: 0.5993 - val_accuracy: 0.4371 - val_auc: 0.5026 - val_loss: 0.8233 - val_precision: 0.5912 - val_recall: 0.2003
# 1955/1955 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step
# Accuracy: 0.4258
# F1 Score: 0.1093
# ROC AUC: 0.5463
# Confusion Matrix:
# [[24423   594]
#  [35317  2203]]
# Precision: 0.7876
# Recall: 0.0587
# (0.4257639477429362,
#  0.1092839248952055,
#  np.float64(0.5462813011033094),
#  array([[24423,   594],
#         [35317,  2203]]),
#  0.7876296031462281,
#  0.058715351812366735)

# %% [markdown]
# **TUNER**

# %%
from keras_tuner import RandomSearch
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import AUC, Precision, Recall

def train_lstm_with_tuner(
    X_train,
    X_test,
    y_train,
    y_test,
    class_weight=None,
    max_trials=10,
    executions_per_trial=1,
    epochs=10,
    batch_size=32,
    patience=4,
    threshold=0.5
):
    def build_model(hp):
        model = models.Sequential()
        model.add(layers.Input(shape=(X_train.shape[1], X_train.shape[2])))

        model.add(layers.Bidirectional(layers.LSTM(
            units=hp.Int("lstm_units1", 32, 128, step=32),
            return_sequences=True
        )))
        model.add(layers.BatchNormalization())
        model.add(layers.Dropout(hp.Float("dropout1", 0.2, 0.5, step=0.1)))

        model.add(layers.Bidirectional(layers.LSTM(
            units=hp.Int("lstm_units2", 16, 64, step=16),
            return_sequences=False
        )))
        model.add(layers.BatchNormalization())
        model.add(layers.Dropout(hp.Float("dropout2", 0.2, 0.5, step=0.1)))

        model.add(layers.Dense(
            hp.Int("dense_units", 32, 128, step=32),
            activation='relu'
        ))
        model.add(layers.Dropout(hp.Float("dropout3", 0.2, 0.5, step=0.1)))

        model.add(layers.Dense(1, activation="sigmoid"))

        model.compile(
            optimizer=Adam(learning_rate=hp.Choice("lr", [1e-3, 1e-4])),
            loss=BinaryCrossentropy(),
            metrics=["accuracy", AUC(name='auc'), Precision(), Recall()]
        )
        return model

    tuner = RandomSearch(
        build_model,
        objective="val_auc",
        max_trials=max_trials,
        executions_per_trial=executions_per_trial,
        directory="tuner_dir",
        project_name="lstm_opt"
    )

    early_stop = EarlyStopping(monitor="val_auc", patience=patience, mode="max", restore_best_weights=True)

    tuner.search(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop],
        class_weight=class_weight,
        verbose=2
    )

    tuner.results_summary()
    best_hp = tuner.get_best_hyperparameters(1)[0]

    print("\n🔧 Mejor configuración encontrada:")
    for k in best_hp.values:
        print(f"{k}: {best_hp.get(k)}")

    best_model = tuner.get_best_models(1)[0]
    y_prob = best_model.predict(X_test).flatten()
    y_pred = (y_prob > threshold).astype(int)

    return best_model, X_test, y_test, y_prob, y_pred

# %%
df_full["target_3m"] = (df_full["ret_next_3m"] > 0.05).astype(int)
df_full["target_6m"] = (df_full["ret_next_6m"] > 0.05).astype(int)
df_full["target_1y"] = (df_full["ret_next_1y"] > 0.05).astype(int)
# Selección de top 100 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(100)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])
#df_clean.to_csv("1_df_clean_ordenado.csv",sep=";")


# Limpieza con imputación
df_clean = clean_columns(df_clean)
#df_clean.to_csv("2_df_cleean_limpio.csv",sep=";")

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data(
    df_clean,
    targets=targets
)
#df_processed_minmax.to_csv("3_df_processed_minmax_escalado.csv", sep=";")



# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 90
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_lstm_with_tuner(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    class_weight=weight_dict,
    max_trials=10,
    executions_per_trial=1,
    epochs=10,
    batch_size=32,
    patience=4
)

# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
# Trial 9 Complete [00h 35m 42s]
# val_auc: 0.5479590892791748
#
# Best val_auc So Far: 0.5930365324020386
# Total elapsed time: 05h 57m 16s
#
# Search: Running Trial #10
#
# Value             |Best Value So Far |Hyperparameter
# 96                |128               |lstm_units1
# 0.2               |0.3               |dropout1
# 32                |16                |lstm_units2
# 0.4               |0.2               |dropout2
# 96                |128               |dense_units
# 0.2               |0.3               |dropout3
# 0.001             |0.0001            |lr
#
# Epoch 1/10
# 15290/15290 - 365s - 24ms/step - accuracy: 0.5043 - auc: 0.5046 - loss: 0.6948 - precision: 0.4865 - recall: 0.4682 - val_accuracy: 0.4849 - val_auc: 0.5010 - val_loss: 0.6930 - val_precision: 0.4842 - val_recall: 0.9997
# Epoch 2/10
# 15290/15290 - 358s - 23ms/step - accuracy: 0.5006 - auc: 0.5033 - loss: 0.6932 - precision: 0.4851 - recall: 0.5496 - val_accuracy: 0.5299 - val_auc: 0.5430 - val_loss: 0.7463 - val_precision: 0.5124 - val_recall: 0.5760
# Epoch 3/10
# 15290/15290 - 359s - 23ms/step - accuracy: 0.5308 - auc: 0.5454 - loss: 0.6902 - precision: 0.5128 - recall: 0.5775 - val_accuracy: 0.5165 - val_auc: 0.5303 - val_loss: 0.6941 - val_precision: 0.5009 - val_recall: 0.0719
# Epoch 4/10

# %%
def save_trained_model_and_scaler(model, scaler, feature_cols, model_name, target_column, folder_path='/content/drive/MyDrive/modelos_lstm'):
    """
    Save trained LSTM model, corresponding scaler, and feature columns.

    Args:
        model: Trained Keras model object.
        scaler: Fitted scaler (e.g., MinMaxScaler).
        feature_cols (List[str]): Ordered list of feature column names.
        model_name (str): Identifier name for model (e.g. "improved_lstm").
        target_column (str): Target variable name (e.g. "target_6m").
        folder_path (str): Directory path where to save model, scaler, and features.
    """
    import os
    import joblib
    from tensorflow.keras.models import save_model

    os.makedirs(folder_path, exist_ok=True)

    model_path = f"{folder_path}/{model_name}.keras"
    scaler_path = f"{folder_path}/scaler_{model_name}.pkl"
    features_path = f"{folder_path}/features_{model_name}.pkl"

    save_model(model, model_path)
    joblib.dump(scaler, scaler_path)
    joblib.dump(feature_cols, features_path)

    print(f"Modelo guardado en: {model_path}")
    print(f"Scaler guardado en: {scaler_path}")
    print(f"Features guardadas en: {features_path}")

# %% [markdown]
# # Random forest para feature importance...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer


# 1. Definir target
df_full["target_3m"] = (df_full["ret_next_3m"] > 0.05).astype(int)
df_full["target_6m"] = (df_full["ret_next_6m"] > 0.05).astype(int)
df_full["target_1y"] = (df_full["ret_next_1y"] > 0.05).astype(int)


# 2. Selección top símbolos
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(500)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])


# Codificación de categóricas si existieran (seguridad)
for col in df_clean.select_dtypes(include=["object", "category"]).columns:
    df_clean[col] = LabelEncoder().fit_transform(df_clean[col].astype(str))

# 3. Random Forest para obtener top features
df_rf = df_clean.drop(columns=["symbol", "date"], errors="ignore").copy()
targets = ['target_3m', 'target_6m', 'target_1y']
X_rf = df_rf.drop(columns=targets)
y_rf = df_rf["target_6m"]

X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(X_rf, y_rf, test_size=0.2, random_state=42)
rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
rf.fit(X_train_rf, y_train_rf)
importances = pd.Series(rf.feature_importances_, index=X_rf.columns)
top_features = importances.sort_values(ascending=False).head(20).index.tolist()
print("Top 20 features seleccionadas:")
print(top_features)

# %%
def prepare_data_custom(df, targets):
    symbol_col = df["symbol"]
    date_col = df["date"]
    df = df.drop(columns=["symbol", "date"], errors="ignore")

    for col in df.select_dtypes(include=["object", "category"]).columns:
        df[col] = LabelEncoder().fit_transform(df[col].astype(str))

    feature_cols = [col for col in df.columns if col not in targets]
    X = df[feature_cols]
    y = df[targets]

    imputer = SimpleImputer(strategy="mean")
    X_imputed = imputer.fit_transform(X)
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X_imputed)

    df_scaled = pd.DataFrame(X_scaled, columns=feature_cols, index=df.index)
    df_scaled = pd.concat([df_scaled, y], axis=1)
    df_scaled["symbol"] = symbol_col.values
    df_scaled["date"] = date_col.values
    return df_scaled, scaler

# %%
# Selección de top 100 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(200)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])
#df_clean.to_csv("1_df_clean_ordenado.csv",sep=";")


# Limpieza con imputación
#df_clean = clean_columns(df_clean)
top_features = [
    'close_v', 'low', 'high', 'open_v', 'sma_5', 'prev_close',
    'ema_12', 'ema_26', 'bollinger_upper', 'sma_20',
    'bollinger_lower', 'var_95', 'atr_14', 'volume'
]
df_clean = df_clean[top_features + ['target_3m', 'target_6m', 'target_1y', 'symbol', 'date']].copy()

# Preprocesado (sin imputar aquí)
df_processed_minmax, scaler_minmax = prepare_data_custom(df_clean, ['target_3m', 'target_6m', 'target_1y'])


# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 90
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax, target_column, sequence_length, test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_improved_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    class_weight=weight_dict
)

# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)

# %% [markdown]
# # INCLUYENDO SYMBOL Y DATE ...

# %%
def prepare_data_with_symbol_date(df: pd.DataFrame, targets: list):
    """
    Prepares a DataFrame for LSTM modeling: encodes 'symbol', extracts 'date' features,
    imputes missing values, and applies MinMax scaling.

    Args:
        df (pd.DataFrame): Input data with features + target + symbol + date.
        targets (list): List of target column names.

    Returns:
        pd.DataFrame: Scaled dataframe with 'symbol' and 'date' incorporated as features.
        MinMaxScaler: The fitted scaler object.
    """
    df_clean = df.copy()

    # Convert date and extract features
    df_clean["date"] = pd.to_datetime(df_clean["date"], errors="coerce")
    df_clean["year"] = df_clean["date"].dt.year
    df_clean["month"] = df_clean["date"].dt.month
    df_clean["dayofweek"] = df_clean["date"].dt.dayofweek

    date_col = df_clean["date"]  # store datetime (not string)

    # Encode symbol (remains numeric)
    df_clean["symbol"] = LabelEncoder().fit_transform(df_clean["symbol"].astype(str))

    # Drop original date before scaling
    df_clean = df_clean.drop(columns=["date"], errors="ignore")

    for col in df_clean.select_dtypes(include=["object", "category"]).columns:
        df_clean[col] = LabelEncoder().fit_transform(df_clean[col].astype(str))

    feature_cols = [col for col in df_clean.columns if col not in targets]
    X = df_clean[feature_cols]
    y = df_clean[targets]

    imputer = SimpleImputer(strategy="mean")
    X_imputed = imputer.fit_transform(X)
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X_imputed)

    df_scaled = pd.DataFrame(X_scaled, columns=feature_cols, index=df_clean.index)
    df_scaled = pd.concat([df_scaled, y], axis=1)

    # Reattach encoded symbol and original date
    df_scaled["symbol"] = df_clean["symbol"].values
    df_scaled["date"] = date_col.values

    print(f"columnas scaler: {X.columns}")
    return df_scaled, scaler

# %%
import sys
def build_and_split_sequences_by_symbol(
    df: pd.DataFrame,
    target_column: str,
    sequence_length: int = 60,
    test_size: float = 0.2
):
    """
    Builds sequential data for each symbol independently and performs temporal train-test split.

    Args:
        df (pd.DataFrame): Preprocessed DataFrame with features, target, 'symbol' and 'date'.
        target_column (str): Column name for binary target.
        sequence_length (int): Time window for each sequence.
        test_size (float): Proportion of test samples (applied per symbol).

    Returns:
        Tuple of numpy arrays: X_train, X_test, y_train, y_test
    """
    X_train, y_train, X_test, y_test = [], [], [], []

    symbols = df["symbol"].unique()
    for symbol in symbols:
        df_symbol = df[df["symbol"] == symbol].copy()
        df_symbol = df_symbol.sort_values("date")

        if len(df_symbol) <= sequence_length:
            continue  # Skip if not enough data

        df_symbol[target_column] = df_symbol[target_column].astype(int)
        features = df_symbol.drop(
            columns=["date", "target_3m", "target_6m", "target_1y"],
            errors="ignore"
        )

        print(f" las features son : {features.columns}")
        target = df_symbol[target_column].values

        split_idx = int(len(features) * (1 - test_size))
        for i in range(len(features) - sequence_length):
            if i + sequence_length >= len(features):
                continue

            X_seq = features.iloc[i:i + sequence_length].values.astype(np.float32)
            y_val = target[i + sequence_length]

            if i + sequence_length < split_idx:
                X_train.append(X_seq)
                y_train.append(y_val)
            else:
                X_test.append(X_seq)
                y_test.append(y_val)

    return (
        np.array(X_train),
        np.array(X_test),
        np.array(y_train),
        np.array(y_test)
    )

# %%
df_full["target_3m"] = (df_full["ret_next_3m"] > 0.05).astype(int)
df_full["target_6m"] = (df_full["ret_next_6m"] > 0.05).astype(int)
df_full["target_1y"] = (df_full["ret_next_1y"] > 0.05).astype(int)
# Selección de top 50 símbolos con más histórico
top_symbols = (
    df_full.groupby("symbol")
    .size()
    .sort_values(ascending=False)
    .head(50)
    .index
)
df_clean = df_full[df_full["symbol"].isin(top_symbols)].copy()
df_clean = df_clean.sort_values(by=["symbol", "date"])
#df_clean.to_csv("1_df_clean_ordenado.csv",sep=";")


# Limpieza con imputación
df_clean = clean_columns(df_clean)

# Preprocesado (sin imputar aquí)
targets = ['target_3m', 'target_6m', 'target_1y']
df_processed_minmax, scaler_minmax = prepare_data_with_symbol_date(
    df_clean,
    targets=targets
)


# Secuenciado correcto por símbolo
target_column = 'target_6m'
sequence_length = 60
X_train, X_test, y_train, y_test = build_and_split_sequences_by_symbol(
    df_processed_minmax,
    target_column=target_column,
    sequence_length=sequence_length,
    test_size=0.2
)

# Pesos balanceados
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.flatten()
)
weight_dict = {0: weights[0], 1: weights[1]}

# Entrenamiento
model, X_test, y_test, y_prob, y_pred = train_improved_lstm_classifier(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    sequence_length=sequence_length,
    class_weight=weight_dict
)

# Evaluación
model_evaluation(
    y_test=pd.Series(y_test),
    y_pred=pd.Series(y_pred),
    y_prob=pd.Series(y_prob)
)
# Out:
# Shape before: (312565, 56)
# Shape after: (312565, 32)
# columnas scaler: Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
#  las features son : Index(['symbol', 'close_v', 'volume', 'prev_close', 'prev_volume',
#        'daily_return', 'close_change_pct', 'intraday_volatility', 'log_return',
#        'volume_change_pct', 'sma_20', 'delta', 'gain', 'loss', 'rsi_14',
#        'rel_volume', 'ema_26', 'macd_signal', 'macd_histogram', 'true_range',
#        'atr_14', 'candle_body', 'upper_wick', 'lower_wick', 'candle_color',
#        'momentum_10', 'roc_10', 'var_95', 'year', 'month', 'dayofweek'],
#       dtype='object')
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 172s 21ms/step - accuracy: 0.5018 - auc: 0.5084 - loss: 0.7910 - precision: 0.4834 - recall: 0.5845 - val_accuracy: 0.4860 - val_auc: 0.5034 - val_loss: 0.7029 - val_precision: 0.5732 - val_recall: 0.0443
# Epoch 2/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 160s 21ms/step - accuracy: 0.5189 - auc: 0.5305 - loss: 0.6958 - precision: 0.4989 - recall: 0.5210 - val_accuracy: 0.5024 - val_auc: 0.5110 - val_loss: 0.7055 - val_precision: 0.5158 - val_recall: 0.6967
# Epoch 3/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.5394 - auc: 0.5606 - loss: 0.6875 - precision: 0.5178 - recall: 0.5682 - val_accuracy: 0.5175 - val_auc: 0.5221 - val_loss: 0.7019 - val_precision: 0.5289 - val_recall: 0.6573
# Epoch 4/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.5594 - auc: 0.5870 - loss: 0.6810 - precision: 0.5364 - recall: 0.5974 - val_accuracy: 0.5197 - val_auc: 0.5239 - val_loss: 0.7077 - val_precision: 0.5716 - val_recall: 0.3037
# Epoch 5/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.5747 - auc: 0.6111 - loss: 0.6728 - precision: 0.5498 - recall: 0.6247 - val_accuracy: 0.5140 - val_auc: 0.5315 - val_loss: 0.7067 - val_precision: 0.5550 - val_recall: 0.3290
# Epoch 6/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.5872 - auc: 0.6281 - loss: 0.6659 - precision: 0.5612 - recall: 0.6247 - val_accuracy: 0.5115 - val_auc: 0.5288 - val_loss: 0.7128 - val_precision: 0.5498 - val_recall: 0.3337
# Epoch 7/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.5943 - auc: 0.6386 - loss: 0.6610 - precision: 0.5682 - recall: 0.6427 - val_accuracy: 0.5240 - val_auc: 0.5261 - val_loss: 0.7194 - val_precision: 0.5551 - val_recall: 0.4249
# Epoch 8/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.6036 - auc: 0.6517 - loss: 0.6552 - precision: 0.5783 - recall: 0.6395 - val_accuracy: 0.5342 - val_auc: 0.5351 - val_loss: 0.7184 - val_precision: 0.5608 - val_recall: 0.4802
# Epoch 9/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.6182 - auc: 0.6670 - loss: 0.6481 - precision: 0.5947 - recall: 0.6378 - val_accuracy: 0.5258 - val_auc: 0.5414 - val_loss: 0.7170 - val_precision: 0.5370 - val_recall: 0.6369
# Epoch 10/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.6295 - auc: 0.6824 - loss: 0.6393 - precision: 0.6108 - recall: 0.6273 - val_accuracy: 0.5438 - val_auc: 0.5499 - val_loss: 0.7083 - val_precision: 0.5620 - val_recall: 0.5549
# Epoch 11/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 162s 21ms/step - accuracy: 0.6393 - auc: 0.6951 - loss: 0.6317 - precision: 0.6210 - recall: 0.6339 - val_accuracy: 0.5023 - val_auc: 0.5204 - val_loss: 0.7923 - val_precision: 0.5129 - val_recall: 0.8477
# Epoch 12/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 162s 21ms/step - accuracy: 0.6469 - auc: 0.7048 - loss: 0.6249 - precision: 0.6282 - recall: 0.6378 - val_accuracy: 0.5294 - val_auc: 0.5335 - val_loss: 0.7393 - val_precision: 0.5629 - val_recall: 0.4236
# Epoch 13/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.6558 - auc: 0.7159 - loss: 0.6176 - precision: 0.6372 - recall: 0.6504 - val_accuracy: 0.5331 - val_auc: 0.5372 - val_loss: 0.7334 - val_precision: 0.5726 - val_recall: 0.4021
# Epoch 14/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.6637 - auc: 0.7273 - loss: 0.6090 - precision: 0.6480 - recall: 0.6579 - val_accuracy: 0.5176 - val_auc: 0.5203 - val_loss: 0.7758 - val_precision: 0.5590 - val_recall: 0.3416
# Epoch 15/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 161s 21ms/step - accuracy: 0.6701 - auc: 0.7376 - loss: 0.6006 - precision: 0.6537 - recall: 0.6663 - val_accuracy: 0.5325 - val_auc: 0.5296 - val_loss: 0.7568 - val_precision: 0.5758 - val_recall: 0.3824
# Epoch 16/30
# 7720/7720 ━━━━━━━━━━━━━━━━━━━━ 162s 21ms/step - accuracy: 0.6786 - auc: 0.7468 - loss: 0.5927 - precision: 0.6610 - recall: 0.6780 - val_accuracy: 0.5275 - val_auc: 0.5199 - val_loss: 0.7718 - val_precision: 0.5658 - val_recall: 0.3916
# 1955/1955 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step
# Accuracy: 0.5438
# F1 Score: 0.5584
# ROC AUC: 0.5499
# Confusion Matrix:
# [[15968 14058]
#  [14471 18040]]
# Precision: 0.5620
# Recall: 0.5549
# (0.5438060668084495,
#  0.5584361311891533,
#  np.float64(0.5499480797140361),
#  array([[15968, 14058],
#         [14471, 18040]]),
#  0.5620287868403016,
#  0.5548891144535696)

# %% [markdown]
# # Almacenando un modelo

# %%
def save_trained_model_and_scaler(model, scaler, feature_cols, model_name, target_column, folder_path='pkls'):
    import os
    import joblib
    from tensorflow.keras.models import save_model

    os.makedirs(folder_path, exist_ok=True)

    save_model(model, os.path.join(folder_path, f"{model_name}.keras"))
    joblib.dump(scaler, os.path.join(folder_path, f"scaler_{model_name}.pkl"))
    joblib.dump(feature_cols, os.path.join(folder_path, f"features_{model_name}.pkl"))

    print(f"Modelo guardado en: {model_name}.keras")
    print(f"Scaler guardado en: scaler_{model_name}.pkl")
    print(f"Features guardadas en: features_{model_name}.pkl")

# %%
feature_cols = df_clean.columns
feature_cols = [col for col in feature_cols if not col.startswith("target_")]
print(len(feature_cols))

model_name = "improved_lstm"
save_trained_model_and_scaler(model, scaler_minmax, feature_cols, model_name, "target_6m")
# Out:
# 29
# Modelo guardado en: improved_lstm.keras
# Scaler guardado en: scaler_improved_lstm.pkl
# Features guardadas en: features_improved_lstm.pkl
